# %%
# !pip install pandasai --user

# %%
from pandasai import SmartDataframe
from pandasai import PandasAI

import pandas as pd

# %%
from google.colab import files
import io

uploaded = files.upload()

for filename in uploaded.keys():
    data = pd.read_csv(filename)
# Out:
#      <input type="file" id="files-da06676b-5ed4-45c0-adc1-fbe784a930c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da06676b-5ed4-45c0-adc1-fbe784a930c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pandasai.llm.openai import OpenAI

llm = OpenAI(api_token="your API Key")
pandas_ai = PandasAI(llm) # Instantiating as an LLM
# Out:
# /root/.local/lib/python3.10/site-packages/pandasai/__init__.py:145: UserWarning: `PandasAI` (class) is deprecated since v1.0 and will be removed in a future release. Please use `SmartDataframe` instead.
#   warnings.warn(

# %%
pandas_ai.run(data, "chart the survivor count for each sex and use different colored bars?")

# %%
pandas_ai(data, "can you draw a 2D correlation matrix with size 8 x 6")
# Out:
# <string>:20: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
pandas_ai(data, "can you draw a distplot showing corelation between Survived and Fare and ignore warnings")
# Out:
# WARNING:pandasai.helpers.logger:Failed to execute code with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/root/.local/lib/python3.10/site-packages/pandasai/smart_datalake/__init__.py", line 337, in chat
#     result = self._code_manager.execute_code(
#   File "/root/.local/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 217, in execute_code
#     code_to_run = self._clean_code(code)
#   File "/root/.local/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 401, in _clean_code
#     self._check_imports(node)
#   File "/root/.local/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 466, in _check_imports
#     raise BadImportError(library)
# pandasai.exceptions.BadImportError: Generated code includes import of warnings which is not in whitelist.
# . Retrying
# <string>:22: UserWarning:
#
# ...

# %%
pandas_ai(data, "can you draw a distplot showing corelation between Survived and Fare size 12, 8 and ignore warnings")
# Out:
# <string>:22: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# <string>:23: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# <string>:22: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
pandas_ai(data, "can you give me a quote to motivate myself")
# Out:
# WARNING:pandasai.helpers.logger:Failed to execute code with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/root/.local/lib/python3.10/site-packages/pandasai/smart_datalake/__init__.py", line 337, in chat
#     result = self._code_manager.execute_code(
#   File "/root/.local/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 217, in execute_code
#     code_to_run = self._clean_code(code)
#   File "/root/.local/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 401, in _clean_code
#     self._check_imports(node)
#   File "/root/.local/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 466, in _check_imports
#     raise BadImportError(library)
# pandasai.exceptions.BadImportError: Generated code includes import of random which is not in whitelist.
# . Retrying
# "Don't watch the clock; do what it does. Keep going."

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
pandas_ai(data, "can you change the datatype of Survived, Age to int and Pclass, Sex to category and make changes in original data")
# Out:
# WARNING:pandasai.helpers.logger:Failed to execute code with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/root/.local/lib/python3.10/site-packages/pandasai/smart_datalake/__init__.py", line 337, in chat
#     result = self._code_manager.execute_code(
#   File "/root/.local/lib/python3.10/site-packages/pandasai/helpers/code_manager.py", line 244, in execute_code
#     return analyze_data(self._get_originals(dfs))
#   File "<string>", line 20, in analyze_data
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/generic.py", line 6240, in astype
#     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py", line 448, in astype
#     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
# ...

# %%
  data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pandas_ai(data, "of which Age group has the most person died")
# Out:
# 'The most common age group of people who died is 21.0 years old.'

# %%
pandas_ai(data, "can you draw a pie chart showing relation between Embarked and Survived?")
# Out:
# <string>:22: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
# <string>:22: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.

# %%
pandas_ai.run(data, "can you drop cabin column from data")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pandas_ai(data, "can you show outliers in the dataset via box plot and increase the size of the chart")
